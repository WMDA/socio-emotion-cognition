# %% [markdown]
# # Task differences

# %%
import beahvioural_functions as bf
import statsmodels.formula.api as smf
import pandas as pd
import ptitprince as pt
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
tasks = { 'eft_simple': bf.get_mean_rt_df('eft', 'SimpleFigures'), 
         'eft_complex': bf.get_mean_rt_df('eft', 'ComplexFigures'), 
         'fear_faces': bf.get_mean_rt_df('fear', 'fear'),
         'partial_fear': bf.get_mean_rt_df('fear', 'Partially_fear'),
         'happy_faces': bf.get_mean_rt_df('happy', 'happy'),
         'partial_happy': bf.get_mean_rt_df('happy', 'Partially_happy'),

}
# Out:
# [Errno 2] No such file or directory: '/data/project/BEACONB/CNSCNSD/bids_t1/sub-G2127/func/sub-G2127_task-eft_events.tsv'
# [Errno 2] No such file or directory: '/data/project/BEACONB/CNSCNSD/bids_t1/sub-G2127/func/sub-G2127_task-eft_events.tsv'
# [Errno 2] No such file or directory: '/data/project/BEACONB/CNSCNSD/bids_t1/sub-G2127/func/sub-G2127_task-fear_events.tsv'
# [Errno 2] No such file or directory: '/data/project/BEACONB/CNSCNSD/bids_t1/sub-G2127/func/sub-G2127_task-fear_events.tsv'
# [Errno 2] No such file or directory: '/data/project/BEACONB/CNSCNSD/bids_t1/sub-G2127/func/sub-G2127_task-happy_events.tsv'
# [Errno 2] No such file or directory: '/data/project/BEACONB/CNSCNSD/bids_t1/sub-G2127/func/sub-G2127_task-happy_events.tsv'

# %%
smf.mixedlm('rt ~ group + time + group:time', data=tasks['eft_complex'], groups='sub').fit().summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:                   MixedLM      Dependent Variable:      rt
# No. Observations:        184          Method:                  REML
# No. Groups:              92           Scale:                   548683.6732
# Min. group size:         2            Log-Likelihood:          -1476.4618
# Max. group size:         2            Converged:               Yes
# Mean group size:         2.0
# --------------------------------------------------------------------------
#                          Coef.    Std.Err.   z    P>|z|   [0.025   0.975]
# --------------------------------------------------------------------------
# Intercept                4614.283  106.997 43.125 0.000  4404.572 4823.994
# group[T.HC]              -672.612  197.508 -3.405 0.001 -1059.721 -285.503
# time[T.t2]               -552.221  129.933 -4.250 0.000  -806.884 -297.557
# group[T.HC]:time[T.t2]    601.727  239.845  2.509 0.012   131.638 1071.815
# sub Var                195465.760  133.711
# ==========================================================================
#
# """

# %%
smf.mixedlm('rt ~ group + time + group:time', data=tasks['eft_simple'], groups='sub').fit().summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                   MixedLM      Dependent Variable:      rt
# No. Observations:        184          Method:                  REML
# No. Groups:              92           Scale:                   94063.6885
# Min. group size:         2            Log-Likelihood:          -1347.1607
# Max. group size:         2            Converged:               Yes
# Mean group size:         2.0
# -------------------------------------------------------------------------
#                          Coef.    Std.Err.   z    P>|z|  [0.025   0.975]
# -------------------------------------------------------------------------
# Intercept                1573.322   55.732 28.230 0.000 1464.090 1682.554
# group[T.HC]               -14.489  102.876 -0.141 0.888 -216.122  187.144
# time[T.t2]               -156.023   53.798 -2.900 0.004 -261.466  -50.580
# group[T.HC]:time[T.t2]    196.965   99.307  1.983 0.047    2.327  391.604
# sub Var                107827.133  106.447
# =========================================================================
#
# """

# %%
smf.mixedlm('rt ~ group + time + group:time', data=tasks['fear_faces'], groups='sub').fit().summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                 MixedLM      Dependent Variable:      rt
# No. Observations:      184          Method:                  REML
# No. Groups:            92           Scale:                   24846.8050
# Min. group size:       2            Log-Likelihood:          -1212.7519
# Max. group size:       2            Converged:               Yes
# Mean group size:       2.0
# -----------------------------------------------------------------------
#                          Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# -----------------------------------------------------------------------
# Intercept                950.014   25.419 37.374 0.000  900.194 999.834
# group[T.HC]              -37.082   46.921 -0.790 0.429 -129.046  54.881
# time[T.t2]               -73.123   27.650 -2.645 0.008 -127.316 -18.930
# group[T.HC]:time[T.t2]    23.588   51.039  0.462 0.644  -76.448 123.623
# sub Var                17150.608   39.555
# =======================================================================
#
# """

# %%
smf.mixedlm('rt ~ group + time + group:time', data=tasks['partial_fear'], groups='sub').fit().summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                 MixedLM      Dependent Variable:      rt
# No. Observations:      184          Method:                  REML
# No. Groups:            92           Scale:                   20612.0214
# Min. group size:       2            Log-Likelihood:          -1202.9010
# Max. group size:       2            Converged:               Yes
# Mean group size:       2.0
# -----------------------------------------------------------------------
#                          Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# -----------------------------------------------------------------------
# Intercept                909.672   24.478 37.162 0.000  861.696 957.649
# group[T.HC]              -40.235   45.185 -0.890 0.373 -128.796  48.325
# time[T.t2]               -43.125   25.184 -1.712 0.087  -92.484   6.234
# group[T.HC]:time[T.t2]    -9.696   46.487 -0.209 0.835 -100.808  81.417
# sub Var                18335.065   42.057
# =======================================================================
#
# """

# %%
smf.mixedlm('rt ~ group + time + group:time', data=tasks['partial_happy'], groups='sub').fit().summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                  MixedLM      Dependent Variable:      rt
# No. Observations:       184          Method:                  REML
# No. Groups:             92           Scale:                   29187.1322
# Min. group size:        2            Log-Likelihood:          -1234.0157
# Max. group size:        2            Converged:               Yes
# Mean group size:        2.0
# ------------------------------------------------------------------------
#                          Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# ------------------------------------------------------------------------
# Intercept                951.506   29.083 32.717 0.000  894.505 1008.507
# group[T.HC]                8.264   53.684  0.154 0.878  -96.955  113.483
# time[T.t2]               -27.298   29.968 -0.911 0.362  -86.033   31.438
# group[T.HC]:time[T.t2]   -42.499   55.318 -0.768 0.442 -150.920   65.923
# sub Var                25790.152   49.833
# ========================================================================
#
# """

# %%
smf.mixedlm('rt ~ group + time + group:time', data=tasks['happy_faces'], groups='sub').fit().summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                  MixedLM      Dependent Variable:      rt
# No. Observations:       184          Method:                  REML
# No. Groups:             92           Scale:                   25712.1280
# Min. group size:        2            Log-Likelihood:          -1218.7372
# Max. group size:        2            Converged:               Yes
# Mean group size:        2.0
# ------------------------------------------------------------------------
#                          Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# ------------------------------------------------------------------------
# Intercept                958.902   26.458 36.243 0.000  907.046 1010.758
# group[T.HC]              -12.841   48.839 -0.263 0.793 -108.563   82.881
# time[T.t2]               -46.669   28.127 -1.659 0.097 -101.798    8.459
# group[T.HC]:time[T.t2]   -37.147   51.921 -0.715 0.474 -138.910   64.615
# sub Var                19788.183   42.919
# ========================================================================
#
# """

# %%
for df in tasks.keys():
    print(df)
    display(pd.DataFrame({
        'an_t1_mean': tasks[df][(tasks[df]['time'] == 't1') & (tasks[df]['group'] == 'AN')].mean(),
        'an_t1_std': tasks[df][(tasks[df]['time'] == 't1') & (tasks[df]['group'] == 'AN')].std(),
        'an_t2_mean': tasks[df][(tasks[df]['time'] == 't2') & (tasks[df]['group'] == 'AN')].mean(),
        'an_t2_std': tasks[df][(tasks[df]['time'] == 't2') & (tasks[df]['group'] == 'AN')].std(),
        'hc_t1_mean': tasks[df][(tasks[df]['time'] == 't1') & (tasks[df]['group'] == 'HC')].mean(),
        'hc_t1_mean': tasks[df][(tasks[df]['time'] == 't1') & (tasks[df]['group'] == 'HC')].std(),
        'hc_t2_mean': tasks[df][(tasks[df]['time'] == 't2') & (tasks[df]['group'] == 'HC')].mean(),
        'hc_t2_std': tasks[df][(tasks[df]['time'] == 't2') & (tasks[df]['group'] == 'HC')].std(),
        }
    ).drop('sub', axis=0)
    )
# Out:
# eft_simple
#      an_t1_mean  an_t1_std   an_t2_mean   an_t2_std  hc_t1_mean  hc_t2_mean  \
# rt  1573.322222  396.85827  1417.299145  417.249799  454.015188  1599.77572
#
#      hc_t2_std
# rt  612.656439
# eft_complex
#      an_t1_mean   an_t1_std   an_t2_mean  an_t2_std  hc_t1_mean   hc_t2_mean  \
# rt  4614.282906  809.175839  4062.062393  881.99036  798.273465  3991.176955
#
#      hc_t2_std
# rt  993.973754
# fear_faces
#     an_t1_mean   an_t1_std  an_t2_mean   an_t2_std  hc_t1_mean  hc_t2_mean  \
# rt  950.013846  209.955219  876.890769  194.604209  163.171632  863.396296
#
#      hc_t2_std
# rt  249.789845
# partial_fear
#     an_t1_mean   an_t1_std  an_t2_mean   an_t2_std  hc_t1_mean  hc_t2_mean  \
# rt  909.672308  201.187918  866.547692  194.384848  144.038108  816.616667
#
#      hc_t2_std
# rt  237.152798
# happy_faces
#     an_t1_mean   an_t1_std  an_t2_mean   an_t2_std  hc_t1_mean  hc_t2_mean  \
# rt  958.902308  221.364173  912.233077  198.698112  185.646595  862.244444
#
#     hc_t2_std
# rt  250.46205
# partial_happy
#     an_t1_mean   an_t1_std  an_t2_mean   an_t2_std  hc_t1_mean  hc_t2_mean  \
# rt  951.506154  224.691752  924.208462  240.844429  190.290107  889.974074
#
#      hc_t2_std
# rt  278.106136

# %%
for df in tasks.keys():
    fig,ax = plt.subplots(1,1, figsize=(10, 8))
    pt.RainCloud(
            x="time", 
            y='rt', 
            hue="group", 
            data=tasks[df], 
            palette='Accent_r', 
            alpha=.65, 
            dodge=True, 
            scale="area",
            ax=ax,
            width_viol=.5,
            jitter=0,
            pointplot = True,
            bw=.3,
            
             )
    print(df)
# Out:
# eft_simple
# eft_complex
# fear_faces
# partial_fear
# happy_faces
# partial_happy
