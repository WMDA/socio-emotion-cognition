# %%
import nilearn.plotting as plotting
import nilearn.image as img
import glob
from decouple import config
import os

# %%
path = os.path.join(config('happy'), '2ndlevel', 'fsl_test')#, 'results' )
imgs = glob.glob(f'{path}/*.nii')

# %%
plotting.plot_stat_map(imgs[0])

# %%
linear = img.load_img(f'{path}/linear_all_groups.nii.gz')

# %%
linear.get_fdata()[:,:,1]
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        ...,
#
#        [[nan, nan, nan, ..., nan, nan, nan],
# ...
